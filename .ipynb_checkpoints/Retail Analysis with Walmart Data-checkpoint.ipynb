# %% [markdown]
# ## Retail Analysis with Walmart Data

# %%
#import required libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Understanding the data
walmart=pd.read_csv(r'data\Walmart_Store_sales.csv')
walmart
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
walmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
walmart['Date']=pd.to_datetime(walmart['Date'])
walmart.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# ## Basic Statistics tasks

# %%
# Which store has maximum sales
walmart.groupby('Store').Weekly_Sales.sum().sort_values(ascending=False).head(1).round()
# Out:
# Store
# 20    301397792.0
# Name: Weekly_Sales, dtype: float64

# %%
# Which store has maximum standard deviation i.e., 
#the sales vary a lot. Also, find out the coefficient of mean to standard deviation
walmart.groupby('Store').Weekly_Sales.std().sort_values(ascending=False).round()
# Out:
# Store
# 14    317570.0
# 10    302262.0
# 20    275901.0
# 4     266201.0
# 13    265507.0
# 23    249788.0
# 27    239930.0
# 2     237684.0
# 39    217466.0
# 6     212526.0
# 35    211243.0
# 19    191723.0
# 41    187907.0
# 28    181759.0
# 18    176642.0
# 24    167746.0
# 11    165834.0
# 22    161251.0
# 1     155981.0
# 12    139167.0
# 32    138017.0
# 45    130169.0
# 21    128753.0
# 31    125856.0
# 15    120539.0
# 40    119002.0
# 25    112977.0
# 7     112585.0
# 17    112163.0
# 26    110431.0
# 8     106281.0
# 34    104630.0
# 29     99120.0
# 16     85770.0
# 9      69029.0
# 36     60725.0
# 42     50263.0
# 3      46320.0
# 38     42768.0
# 43     40598.0
# 5      37738.0
# 44     24763.0
# 33     24133.0
# 30     22810.0
# 37     21837.0
# Name: Weekly_Sales, dtype: float64

# %%
Store14=walmart[walmart.Store==14]
cof=Store14.Weekly_Sales.std()/Store14.Weekly_Sales.mean()*100
cof
# Out:
# 15.713673600948338

# %%
# Which store/s has good quarterly growth rate in Q3’2012
q2_start=pd.Timestamp(2012,4,1)
q2_stop=pd.Timestamp(2012,6,30)
q3_start=pd.Timestamp(2012,7,1)
q3_stop=pd.Timestamp(2012,9,30)

# %%
q2walmart=walmart[(walmart['Date']>q2_start) & (walmart['Date']<q2_stop) ]
q3walmart=walmart[(walmart['Date']>q3_start) & (walmart['Date']<q3_stop) ]

# %%
q2=pd.DataFrame(q2walmart.groupby('Store')['Weekly_Sales'].sum())
q2
# Out:
#        Weekly_Sales
# Store
# 1       21036965.58
# 2       25085123.61
# 3        5562668.16
# 4       28384185.16
# 5        4427262.21
# 6       20728970.16
# 7        7613593.92
# 8       11934275.61
# 9        7431320.13
# 10      23598433.93
# 11      17879095.77
# 12      13193365.04
# 13      26803225.55
# 14      24427769.06
# 15       7867952.23
# 16       6626133.44
# 17      12918892.02
# 18      13834706.08
# 19      18315278.56
# 20      27550180.62
# 21       9226279.62
# 22      13329065.39
# 23      18283424.90
# 24      17768191.98
# 25       9247467.19
# 26      13218289.66
# 27      22593640.73
# 28      16985999.95
# 29       7034493.19
# 30       5786335.45
# 31      18249155.35
# 32      15415236.21
# 33       3512138.05
# 34      12858027.98
# 35      10753570.97
# 36       4090378.90
# 37       6859777.96
# 38       5732362.70
# 39      20191585.63
# 40      12849747.45
# 41      17560035.88
# 42       7608247.31
# 43       8239792.67
# 44       4322555.33
# ...

# %%
q3=pd.DataFrame(q3walmart.groupby('Store')['Weekly_Sales'].sum())
q3
# Out:
#        Weekly_Sales
# Store
# 1       18633209.98
# 2       22396867.61
# 3        4966495.93
# 4       25652119.35
# 5        3880621.88
# 6       18341221.11
# 7        7322393.92
# 8       10873860.34
# 9        6528239.56
# 10      21169356.45
# 11      16094363.07
# 12      11777508.50
# 13      24319994.35
# 14      20140430.40
# 15       6909374.37
# 16       6441311.11
# 17      11533998.38
# 18      12507521.72
# 19      16644341.31
# 20      24665938.11
# 21       8403507.99
# 22      11818544.33
# 23      17103654.36
# 24      16125999.86
# 25       8309440.44
# 26      12417575.35
# 27      20191238.11
# 28      15055659.67
# 29       6127862.07
# 30       5181974.44
# 31      16454328.46
# 32      14142164.84
# 33       3177072.43
# 34      11476258.98
# 35      10252122.68
# 36       3578123.58
# 37       6250524.08
# 38       5129297.64
# 39      18899955.17
# 40      11647661.37
# 41      16373588.44
# 42       6830839.86
# 43       7376726.03
# 44       4020486.01
# ...

# %%
# Which store/s has good quarterly growth rate in Q3’2012
q3_growth=q3.merge(q2, on="Store",how='inner')
q3_growth['growth']=q3_growth['Weekly_Sales_x']-q3_growth['Weekly_Sales_y']
q3_growth['growth_per']=(q3_growth['growth']/q3_growth['Weekly_Sales_x']*100)
q3_growth.sort_values(by=['growth_per'],ascending=False).head(5)
# Out:
#        Weekly_Sales_x  Weekly_Sales_y      growth  growth_per
# Store
# 16         6441311.11      6626133.44  -184822.33   -2.869328
# 7          7322393.92      7613593.92  -291200.00   -3.976841
# 35        10252122.68     10753570.97  -501448.29   -4.891166
# 26        12417575.35     13218289.66  -800714.31   -6.448234
# 39        18899955.17     20191585.63 -1291630.46   -6.834040

# %%
#Some holidays have a negative impact on sales. 
# Find out holidays which have higher sales than the mean sales in non-holiday season for all stores together
holiday=walmart[walmart['Holiday_Flag']==1]
holiday
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 6375     45 2011-09-09     746129.56             1        71.48       3.738
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
# 6391     45 2011-12-30     869403.63             1        37.79       3.389
# 6397     45 2012-10-02     803657.12             1        37.00       3.640
# 6427     45 2012-07-09     766512.66             1        75.70       3.911
#
#              CPI  Unemployment
# ...

# %%
Labour_Day=['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06']
Labour_Day=holiday.loc[holiday.Date.isin(Labour_Day)]['Weekly_Sales'].mean()
Labour_Day
# Out:
# 1039182.8339999999

# %%
Thanksgiving=['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29']
Thanksgiving=holiday.loc[holiday.Date.isin(Thanksgiving)]['Weekly_Sales'].mean()
Thanksgiving
# Out:
# 1471273.427777778

# %%
Christmas=['2010-12-31', '2011-12-30', '2012-12-27', '2013-12-28']
Christmas=walmart.loc[walmart.Date.isin(Christmas)]['Weekly_Sales'].mean()
Christmas
# Out:
# 960833.1115555551

# %%
Super_Bowl_s=['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06']
Super_Bowl_s=walmart.loc[walmart.Date.isin(Super_Bowl)]['Weekly_Sales'].mean()
Super_Bowl_s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 Super_Bowl_s=['2010-09-10', '2011-09-09', '2012-09-07', '2013-09-06']
# ----> 2 Super_Bowl_s=walmart.loc[walmart.Date.isin(Super_Bowl)]['Weekly_Sales'].mean()
#       3 Super_Bowl_s
#
# NameError: name 'Super_Bowl' is not defined

# %%
non_holiday=walmart[walmart['Holiday_Flag']==0]['Weekly_Sales'].mean()
non_holiday
# Out:
# 1041256.3802088564

# %% [markdown]
# ##  Hence Thanksgiving have higher sales than the mean sales in non-holiday season for all stores together

# %%
# Provide a monthly and semester view of sales in units and give insights
walmart['Month']=pd.DatetimeIndex(walmart['Date']).month
walmart['Year']=pd.DatetimeIndex(walmart['Date']).year

walmart
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  Month  Year
# ...

# %%
walmart.groupby(['Month']).Weekly_Sales.mean().round().plot(kind='bar')
plt.title('Monthly Sales')
plt.ylabel('Weekly_Sales')
# Out:
# Text(0, 0.5, 'Weekly_Sales')

# %%
walmart.groupby(['Year']).Weekly_Sales.sum().round().plot(kind='bar')
plt.title('Yearly Sales')
plt.ylabel('Weekly_Sales')
# Out:
# Text(0, 0.5, 'Weekly_Sales')

# %% [markdown]
# ## Statistical Model

# %%
## For Store 1 – Build  prediction models to forecast demand
data=walmart[walmart['Store']==1]
data
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1 2010-05-02    1643690.90             0        42.31       2.572
# 1        1 2010-12-02    1641957.44             1        38.51       2.548
# 2        1 2010-02-19    1611968.17             0        39.93       2.514
# 3        1 2010-02-26    1409727.59             0        46.63       2.561
# 4        1 2010-05-03    1554806.68             0        46.50       2.625
# ..     ...        ...           ...           ...          ...         ...
# 138      1 2012-09-28    1437059.26             0        76.08       3.666
# 139      1 2012-05-10    1670785.97             0        68.55       3.617
# 140      1 2012-12-10    1573072.81             0        62.99       3.601
# 141      1 2012-10-19    1508068.77             0        67.97       3.594
# 142      1 2012-10-26    1493659.74             0        69.16       3.506
#
#             CPI  Unemployment  Month  Year
# ...

# %%
## #Change dates into days by creating new variable.

data['Day']=pd.DatetimeIndex(data['Date']).day
data
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0        1 2010-05-02    1643690.90             0        42.31       2.572
# 1        1 2010-12-02    1641957.44             1        38.51       2.548
# 2        1 2010-02-19    1611968.17             0        39.93       2.514
# 3        1 2010-02-26    1409727.59             0        46.63       2.561
# 4        1 2010-05-03    1554806.68             0        46.50       2.625
# ..     ...        ...           ...           ...          ...         ...
# 138      1 2012-09-28    1437059.26             0        76.08       3.666
# 139      1 2012-05-10    1670785.97             0        68.55       3.617
# 140      1 2012-12-10    1573072.81             0        62.99       3.601
# 141      1 2012-10-19    1508068.77             0        67.97       3.594
# 142      1 2012-10-26    1493659.74             0        69.16       3.506
#
#             CPI  Unemployment  Month  Year  Day
# ...

# %%
# # Hypothesize if CPI, unemployment, and fuel price have any impact on sales.
import seaborn as sns
d=data.corr()
ax = plt.subplots(figsize=(15, 8))
ax=sns.heatmap(data=d,annot=True,linewidths=.5)

# %%
## Linear Regression – Utilize variables like date and restructure dates as 1 for 5 Feb 2010 (starting from the earliest date in order). Hypothesize if CPI, unemployment, and fuel price have any impact on sales.
X=data.drop(['Weekly_Sales','Date','Temperature'],axis=1)
y=data['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %% [markdown]
# ## sklearn.linear_model.LinearRegression¶

# %%
#Linear Regression – Utilize variables like date and restructure dates as 1 for 5 Feb 2010 
#(starting from the earliest date in order)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,mean_squared_error,r2_score
reg = LinearRegression().fit(X_train, y_train)
y_pred=reg.predict(X_test)
print(mean_squared_error(y_test, y_pred))
r2_score(y_test, y_pred)*100
# Out:
# 15257323479.765207
# 27.484734551902278

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit(X_train, y_train)
y_pred=regr.predict(X_test)
print(mean_squared_error(y_test, y_pred))
r2_score(y_test, y_pred)*100
# Out:
# 16698374599.928022
# 20.63568238089245

# %%
from sklearn.neighbors import KNeighborsRegressor
neigh = KNeighborsRegressor(n_neighbors=2)
neigh.fit(X_train, y_train)
y_pred=regr.predict(X_test)
print(mean_squared_error(y_test, y_pred))
r2_score(y_test, y_pred)*100
# Out:
# 16698374599.928022
# 20.63568238089245

# %%
lm = LinearRegression()
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lm, X_train, y_train, scoring='r2', cv=5)
print(scores)
print('Mean Score:' ,scores.mean()*100,'%')
# Out:
# [ 0.36282058  0.07454178  0.29539347 -0.11604035  0.06226457]
# Mean Score: 13.57960102076586 %
